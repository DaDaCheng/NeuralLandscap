# %%
import numpy as np
import random
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

from time import time
from torchvision import datasets, transforms

# %% [markdown]
# ## generate data

# %%
transform = transforms.Compose([transforms.ToTensor(),
                              transforms.Normalize((0.5,), (0.5,)),
                              ])
batchsize=64

trainset = datasets.MNIST('../../data', download=True, train=True, transform=transform)
valset = datasets.MNIST('../../data', download=True, train=False, transform=transform)
train_loader = torch.utils.data.DataLoader(trainset, batch_size=batchsize, shuffle=False)
valloader = torch.utils.data.DataLoader(valset, batch_size=batchsize, shuffle=False)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../../data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ../../data/MNIST/raw/train-images-idx3-ubyte.gz to ../../data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../../data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ../../data/MNIST/raw/train-labels-idx1-ubyte.gz to ../../data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../../data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ../../data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../../data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../../data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ../../data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../../data/MNIST/raw
# Processing...
# Done!
# /pytorch/torch/csrc/utils/tensor_numpy.cpp:141: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program.

# %%
dataiter = iter(train_loader)
images, labels = dataiter.next()

print(images.shape)
print(labels.shape)
# Out:
# torch.Size([64, 1, 28, 28])
# torch.Size([64])

# %% [markdown]
# ## Generate network

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hyper-parameters 
input_size = 784
hidden_size1 = 1000

hidden_size2 = 100

hidden_size3 = 100

num_classes = 10
batch_size = batchsize


class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size1,hidden_size2,hidden_size3,num_classes):
        super(NeuralNet, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1) 
        self.hidden_size1 = hidden_size1
        #self.fc1.weight.detach().normal_(0.0, 0.1)
        #self.fc1.bias.detach().normal_(0.0, 0.1)
        
        
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size1, hidden_size2,bias=False)
        #self.fc2.weight.detach().uniform_(-1,1)
        
        
        self.fc3 = nn.Linear(hidden_size2, hidden_size3)
        self.relu2 = nn.ReLU()
        self.fc4 = nn.Linear(hidden_size3, num_classes,bias=False)
        
        self.lsm=nn.LogSoftmax(dim=1)
    
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu1(out)
        out = self.fc2(out)
        
        
        out = self.fc3(out)
        out = self.relu2(out)
        out = self.fc4(out)
        
        out = self.lsm(out)
        return out

# %% [markdown]
# ## Learning Regime Modification

# %%
def LRM(model,i,beta=1.0):
    with torch.no_grad():
        model.fc1.weight[i,:]=model.fc1.weight[i,:]/beta
        model.fc1.bias[i]=model.fc1.bias[i]/beta
        model.fc2.weight[:,i]=model.fc2.weight[:,i]*beta
        
        
def LRM2(model,i,beta=1.0):
    with torch.no_grad():
        model.fc3.weight[i,:]=model.fc3.weight[i,:]/beta
        model.fc3.bias[i]=model.fc3.bias[i]/beta
        model.fc4.weight[:,i]=model.fc4.weight[:,i]*beta
        
        

        

def LRD(model,i):
    with torch.no_grad():
        a=model.fc1.weight[i][0].detach().clone().numpy() 
        b=model.fc1.bias[i].detach().clone().numpy() 
        c=model.fc2.weight[0][i].detach().clone().numpy()
        xx=torch.tensor(-b/a).reshape(-1, 1).to(device).float()
        fout=model(xx).numpy() 
    return [a,b,c],-b/a,c**2-a**2-b**2,fout




    

def adjust(model,images,threshold_u=100.0,threshold_l=0.1,scale=1.0,layernumber=1):
    L=len(images)
    if layernumber==1:
        hs=hidden_size1
    if layernumber==2:
        hs=hidden_size3
    d_=torch.zeros(hs)
    with torch.no_grad():
        for i in range(hs):
            d=0
            for k in range(L):
                image=images[k]
                
                if layernumber==1:
                    l=-model.fc1.weight[i]/model.fc1.bias[i]
                if layernumber==2:
                    l=-model.fc3.weight[i]/model.fc3.bias[i]                

                x_k=1/image
                d_k=torch.abs(torch.sum(l*x_k)-1.0)/torch.norm(x_k)
                d=d+d_k

            d_[i]=d/L
        d_=d_*scale
        d_=d_**2
        d_=torch.min(d_,torch.tensor(threshold_u*1.0))
        d_=torch.max(d_,torch.tensor(threshold_l*1.0))
        
        #print(d_)
        for i in range(hs):
            if layernumber==1:
                LRM(model,i,d_[i])
            if layernumber==2:
                LRM2(model,i,d_[i])
    
activation = {}
def get_activation(name):
    def hook(model, input, output):
        activation[name] = output.detach()
    return hook

# %% [markdown]
# ## Plot function

# %%
def plot_training(model,node_num=1000):
    plt.plot(train_data,train_label,'-o',label=r'$x_j,y_j$')

    
    x= np.linspace(Nmin, Nmax, num=node_num)
    y= np.zeros(node_num)
    with torch.no_grad():
        for i in range(node_num):
            xx=torch.tensor(x[i]).reshape(-1, 1).to(device).float()
            y[i]=model(xx).numpy()
    plt.plot(x,y,'-',label=r'$x,f(x)$')

# %%
print(len(train_loader))
# Out:
# 938

# %% [markdown]
# ## Training

# %%
learning_rate = 0.001
torch.manual_seed(0)
model = NeuralNet(input_size, hidden_size1,hidden_size2,hidden_size3,num_classes).to(device)
ad=True
if ad:
    dataiter = iter(train_loader)
    images, labels = dataiter.next()
    images = images.view(images.shape[0], -1)
    #adjust(model,images,threshold_u=1,threshold_l=0.01,scale=0.8)
    adjust(model,images,threshold_u=10,threshold_l=0.01,scale=0.8)
    #adjust(model,images,threshold_u=10,threshold_l=1,scale=0.8)
    
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate,momentum=0.9)
#optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
criterion = nn.NLLLoss()
num_epochs=700
dev=100
losslist=[]


totalloss=[]



model.fc2.register_forward_hook(get_activation('fc2'))


count=0

for epoch in range(num_epochs):
    loss_epoch=0
    for i, (images, labels) in enumerate(train_loader):  
        

        images = images.view(images.shape[0], -1)
        
        #print(images,labels)
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        
        totalloss.append(loss.item())

        loss_epoch=loss_epoch+loss.item()
        #print(count,loss.item())
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        count=count+1
        if count==50:
            output = model(images)
            adjust(model,activation['fc2'],threshold_u=10,threshold_l=0.01,scale=0.8,layernumber=2)
            
        #if count>500:
        #    break
        
    #if count>500:
    #    break
                
        
        
    loss_epoch=loss_epoch/len(train_loader) 
    losslist.append(loss_epoch)
    if loss_epoch<0.02:
        break
    print ('Epoch [{}/{}], Loss: {:.4f}' .format(epoch+1, num_epochs, loss_epoch))
# Out:
# Epoch [1/700], Loss: 0.5034
# Epoch [2/700], Loss: 0.2239
# Epoch [3/700], Loss: 0.1671
# Epoch [4/700], Loss: 0.1340
# Epoch [5/700], Loss: 0.1132
# Epoch [6/700], Loss: 0.0980
# Epoch [7/700], Loss: 0.0855
# Epoch [8/700], Loss: 0.0758
# Epoch [9/700], Loss: 0.0674
# Epoch [10/700], Loss: 0.0601
# Epoch [11/700], Loss: 0.0540
# Epoch [12/700], Loss: 0.0485
# Epoch [13/700], Loss: 0.0437
# Epoch [14/700], Loss: 0.0393
# Epoch [15/700], Loss: 0.0354
# Epoch [16/700], Loss: 0.0317
# Epoch [17/700], Loss: 0.0288
# Epoch [18/700], Loss: 0.0260
# Epoch [19/700], Loss: 0.0236
# Epoch [20/700], Loss: 0.0212

# %%
# Out:
# 100

# %%
plt.plot(losslist)
plt.plot(totalloss)

# %%
Epoch [1/700], Loss: 1.2010
Epoch [2/700], Loss: 0.3898
Epoch [3/700], Loss: 0.3145
Epoch [4/700], Loss: 0.2723
Epoch [5/700], Loss: 0.2394
Epoch [6/700], Loss: 0.2112
Epoch [7/700], Loss: 0.1872
Epoch [8/700], Loss: 0.1672
Epoch [9/700], Loss: 0.1504
Epoch [10/700], Loss: 0.1361
Epoch [11/700], Loss: 0.1237
Epoch [12/700], Loss: 0.1128
Epoch [13/700], Loss: 0.1033
Epoch [14/700], Loss: 0.0948
Epoch [15/700], Loss: 0.0873
Epoch [16/700], Loss: 0.0805
Epoch [17/700], Loss: 0.0744
Epoch [18/700], Loss: 0.0688
Epoch [19/700], Loss: 0.0637
Epoch [20/700], Loss: 0.0590
Epoch [21/700], Loss: 0.0548
Epoch [22/700], Loss: 0.0508
Epoch [23/700], Loss: 0.0471
Epoch [24/700], Loss: 0.0436
Epoch [25/700], Loss: 0.0405
Epoch [26/700], Loss: 0.0375
Epoch [27/700], Loss: 0.0347
Epoch [28/700], Loss: 0.0322
Epoch [29/700], Loss: 0.0298
Epoch [30/700], Loss: 0.0276
Epoch [31/700], Loss: 0.0256
Epoch [32/700], Loss: 0.0237
Epoch [33/700], Loss: 0.0219
Epoch [34/700], Loss: 0.0203

# %%
with open('bu20_bl20_s20.npy', 'wb') as f:
    np.save(f, [losslisto,losslisto20,losslisto02,losslisto2002])

# %%
plt.plot(losslisto,label=r'$\beta=1$')
plt.plot(losslisto02,label=r'$\beta \in [0.02,1]$')
plt.plot(losslisto20,label=r'$\beta \in [1,20]$')
plt.plot(losslisto2002,label=r'$\beta \in [0.02,20]$')
plt.legend()

plt.savefig('scale0_2zoom.pdf')

# %%
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.view(images.shape[0], -1)

# %%
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.view(images.shape[0], -1)

torch.manual_seed(0)
model = NeuralNet(input_size, hidden_size1, num_classes).to(device)

L=len(images)
d_=torch.zeros(hidden_size1)
with torch.no_grad():
    for i in range(hidden_size1):
        d=0
        for k in range(L):
            image=images[k]
            l=-model.fc1.weight[i]/model.fc1.bias[i]
            x_k=1/image
            d_k=torch.abs(torch.sum(l*x_k)-1.0)/torch.norm(x_k)
            d=d+d_k

        d_[i]=d/L
d_=torch.min(d_,torch.tensor(100.))

# %%
plt.plot(d_)

# %%
d_=torch.min(d_,torch.tensor(1000.0))

# %%
print(model.fc1.bias[i])
# Out:
# tensor(0.0016, grad_fn=<SelectBackward>)

# %%
print(model.fc1.weight[i]/model.fc1.bias[i])
# Out:
# tensor([  0.3938,  12.7157, -18.0815, -16.1082,  -8.1617,   6.6382,   0.1146,
#          18.5251,  -1.4470,   6.5579,  -6.2827,  -3.8895, -21.0913, -14.4674,
#          -8.7751,   1.4026,   9.5192,  14.1560, -14.7944,  -9.3013,   8.7916,
#          19.3746,  -4.0987,  17.5153,  -3.0880,   2.9605,  21.0756, -20.4516,
#         -13.6979,  -5.1716,  -8.2669,  20.1361, -14.1202,  -9.8650, -15.2786,
#         -20.6982, -12.7079,  20.0023,  10.6174,  11.4215,   1.5184, -11.1892,
#           4.3424, -20.8845, -16.4666, -11.4239,  14.7967,  13.7944,  -9.5144,
#          -0.3019,  15.0033,  23.0782,   9.5542,   3.6237,  15.7523, -12.7751,
#           4.7848, -17.0000, -15.1375, -11.1397,  10.8121,   9.6732, -12.8834,
#           7.3105,  12.8501,  -2.5133,   0.9127,   5.1497,  13.8470,  21.7234,
#         -17.6005,  -8.3968,   8.7120,  18.9126,  20.2735,  20.2715,   4.9290,
#         -19.2688,   2.5351, -13.6597, -20.5657,  20.6862,  17.7882, -22.0342,
#           4.8035,  -3.2528,  -3.1630,  -9.8091,   9.2784, -13.0487,   8.6004,
#          11.5367,  16.0326,   8.1634, -23.3639, -16.5572,   9.2263,   2.8140,
#         -20.3292, -15.6924,  19.6629,  14.4786,  -9.3314,  -6.0671, -22.3804,
#          -0.2828, -16.1812, -16.6305,  -0.7414,   3.9529,  -8.7487,  14.0055,
#         -13.2222,  21.1185,  16.0923, -18.5516,  -5.1592,   1.1928,   3.1510,
#           4.8798,   7.9601,   0.2716, -13.0393,   9.0361, -21.5850, -12.9896,
#          -3.3564,  -8.6278,  -3.9808, -16.1546,  -4.4299,   4.7423, -14.4138,
#          -0.5993,  16.9143,  -1.7255,   1.4005,  -1.2010,   5.2750,  14.9720,
#          22.0219,  14.9496,  22.0634,  -1.1962, -20.2632, -11.2524,  14.0553,
#          -2.0543, -12.8949, -18.0382, -21.8798, -13.9028,   2.5792,  16.9926,
#          14.6890, -18.7996,  17.2879, -11.5846,  -2.4710,  -6.0445,  -1.4872,
#          -2.1919, -19.9922, -19.8437,  -2.7072,   1.5445,  -9.6780,   9.0842,
#         -19.8261,  -0.9676,  20.3201,  -9.2181,  19.7918,   6.2800, -23.5410,
#          11.5729,  -3.4754, -10.1021,  19.1503, -12.9288,   6.4354,  -5.8683,
#          14.0421,   5.7115,  12.0769,  12.9478,  -4.9043,  -2.8598, -17.0856,
#          13.7059,  18.0910,  17.3046, -15.2053,   2.1545, -15.5237, -11.8915,
#         -12.6369,   8.1241, -13.0872,  -0.7547,  -0.7886,  11.1440, -21.1770,
#         -18.9357, -13.5397,  16.8304,  -3.4363,  21.1069,   7.0279,  -0.0627,
#          -4.7131,  -4.5703,   2.6714,  -5.3402,   0.6239,   3.9593, -16.3295,
#          -8.6525,  20.2229, -14.6076,   1.5449,  23.9572,   8.7779,   1.1882,
#         -19.1076,  11.6644, -15.8156,  -6.7246,  -9.3080,  -5.2038,  -0.5578,
#          18.4454,   5.3023,  24.7929,  18.7978, -13.0880,   8.1175, -16.0900,
#          -9.8196,   3.3925,   4.6959,  13.2404,  -7.9935,   2.4958,  12.8997,
#         -20.6961,  17.3122, -14.2117,   5.1599,  -2.0925, -10.7997,   3.7040,
#          19.2901,  -6.3224, -13.3533,  -9.1629, -24.7284,   8.0180, -10.9268,
#         -13.8917, -11.4269,  16.2072,  14.6547,  19.1743,   7.9478,  -5.8108,
#          -6.3476,   2.9482,  12.0652,   3.3453,  -9.8631,  -7.6324, -18.5040,
#           6.2395, -11.6297, -15.6520,  23.8059, -13.3179,  -1.6204,   6.6758,
#           1.2772, -14.8148, -18.3684,  16.5734,   2.2344,  17.8030,  -6.2856,
#           8.7816,  -2.9354,  -0.0579, -10.7197,  10.9874,  11.8071,   0.0466,
#          -2.0251, -15.6860,  12.0312, -19.1511,  11.1925,  -4.3336, -10.4660,
#           3.7279, -10.6627,   8.3386,   6.1073, -16.3988,   4.5447,  10.2447,
#           9.5277,  -2.4664, -18.6902,  -4.8462,   6.4766,  -6.8003,  11.8587,
#          19.2742, -10.1111,   3.2119,  14.8238,   7.7398,  10.9224,  12.5651,
#          -9.1151,   5.6997,  17.9798,  22.1410,  15.4554,   3.5291,  11.8140,
#         -11.4377, -17.6745, -16.0883,  26.0624,  16.0457, -14.0666,   9.5163,
#          17.6679,  23.0965,  19.8223,  16.9861,  -5.5990,  -6.3766,  20.9897,
#          14.0295, -12.3134,  24.8236,  13.7971,  18.2273,  -8.4336,  14.9686,
#          -2.9287,  23.4973,   0.0813,  14.5050,   4.3835,  10.5188,  -8.7303,
#          13.4081, -13.5719,   9.1212, -13.1322, -21.3835, -17.2182,  18.4061,
#          12.8198,  21.7664,  18.3213, -20.4578, -15.7241,  -4.3516, -17.5406,
#          13.6691, -18.0864,  -8.0806, -18.0432,  -5.6802,  25.2029,  22.5260,
#          17.5109,  24.2736,  25.3618,  -3.6435,   8.6569,  20.5000,   5.6819,
#          22.1426,  13.4727,  13.5321,  -9.5913,  11.0357,   2.9892,  -4.9045,
#         -12.2179, -12.2257, -17.1103,  15.4325,  15.6389,  -5.8979, -19.8480,
#          10.9404,   6.3756,  -3.6667, -11.6524,  25.3539,  13.6219, -10.9417,
#          25.3528,  19.9455,  -4.3770,  15.5653, -15.5410,  -7.1712,  12.5864,
#          -4.7223, -19.7847, -12.4581,  -9.8051,  -4.2903,   2.5392,  21.5095,
#           1.7726, -13.5410,   1.5181,  11.1097,  10.6608, -25.1746, -11.2504,
#         -24.9789, -15.0246,   4.2126, -16.7733,  11.7223,  22.5341,   7.7557,
#         -11.7303,  -6.7487,   9.6849, -16.2783,   6.1630, -27.6647, -29.6474,
#         -30.3601, -11.3127,   8.7921, -25.6225,  18.7680,  -8.8657,   7.1640,
#           1.5963, -19.9403,  18.9650,  11.8229,  20.9201,   6.8984, -20.3232,
#          14.0298,  -0.3586,   7.9952, -18.5345,  -6.9892, -22.8396, -10.4341,
#           4.4459, -16.4115,  13.6664,  10.6318,  -5.5080, -25.4108, -24.5480,
#         -15.2472,   2.4587,  16.8067,   9.3920,  -2.9223,   8.0896, -21.7025,
#         -18.7851,  11.1092, -12.7633,   9.7207, -18.7411, -15.0468, -21.7019,
#           9.2856,  -3.5167,  17.2903,  12.2037,   9.9875,  -1.2109,  -9.5754,
#          -6.2409,   3.2922,  11.2097, -21.2902,  10.7335, -10.0331, -22.2803,
#         -18.9314,  13.6070,  16.2913, -22.6545,  15.3861,  11.5896,  13.9288,
#          19.7416, -11.6475,   7.3568,   7.3974, -10.7398,   3.8870,  -6.7990,
#          13.1124,  -8.3580,  -8.9107,   4.3878,   4.6722, -15.0886,  -0.6760,
#           9.2363,  -7.2934,   2.9804,  -9.5497,   2.5246, -18.4966, -14.2502,
#         -17.3229,  16.1078,  -9.5611,  -1.1899, -11.3210,  23.0639,  22.6603,
#         -16.5216, -17.8690, -17.0835,  -2.0893,  -9.8515, -18.2417,  -7.4813,
#           5.1179, -12.6107,   4.6000,  -5.3309, -15.3472,  -0.5436,  14.3586,
#         -22.7338,  -4.7558,  -9.0285,  19.4135, -22.5758, -20.9587,  21.7287,
#         -18.7568,   1.5897,  -3.2926,  -5.4127,  -5.0880,  14.8216,   1.6356,
#         -21.4924, -12.8467,  -7.5988,   9.0482, -18.7403,  19.2342,  -3.1989,
#          -1.0866,  17.5099,   9.2639,  18.5768,   9.2620,  -9.4462, -17.9943,
#          -6.4356,  16.9801,  -8.6458, -20.7456,  10.3648,  22.0241,  -7.1708,
#         -20.9206, -21.5410,   5.5076,  -1.4933, -11.1397,   5.0303,   9.1664,
#          18.5801,  18.1411,  -3.2851, -21.4890, -22.5637,  21.1098,  14.5791,
#          15.7701, -16.6097,  23.9415,  21.7120,  17.7217, -20.2669,  -6.8705,
#         -14.9382,  22.4581, -11.0103,  -8.2186,  10.7443, -11.6755, -11.9225,
#          -3.3536,  -2.9438, -17.4009,  19.5452,  -9.6653,   8.3411,  20.2670,
#          11.9879,   3.7703,  19.4864,   2.5420, -11.5634,  21.1491,   9.0592,
#         -15.8804,  -0.3085, -12.8817,  22.7833,  -3.0560, -19.4676,   2.3154,
#          16.8946,   3.8213,   6.3635,   3.8650,   7.1186,  -9.1221, -11.0483,
#         -21.9910, -17.6885,  10.4838, -12.8523,   3.7841,   7.7563,   2.1671,
#         -14.1240,  22.2276, -12.7737,  18.2417, -20.1447,  -7.4011,  10.4397,
#          -8.2665,  24.6079, -12.6451, -17.7791, -11.5741,   5.3853,  24.6225,
#         -10.1879,   7.2072,  -2.7571,  -3.7222,  14.5816, -18.1583,   3.0504,
#          22.6554,  -2.0241,  18.8737,  -6.5432,  18.7120, -21.4069,  -2.7015,
#          -3.4156,   7.9051,   9.3940,  16.9635,  -5.4424,  -3.3921,  11.7123,
#          -8.7874,  20.5853, -13.9290,  -0.3007,  -0.1658,  10.0916,  15.8157,
#          -5.4490, -17.5817,  13.6609,   6.4595,  10.6550, -11.0987,  17.2413,
#          22.9606,   2.9448, -20.1998,  16.2805, -16.3810,   5.7344,   3.8554,
#         -10.0393,   8.4513, -19.6996,   5.6807, -14.5459,  -2.9057,   2.0557,
#          17.4247, -13.0207,  12.1296,  -3.3225, -12.4431, -21.9488, -20.9765,
#          25.5847,  -3.8943,   2.8295,   8.8825,  17.8854,  20.8707,  20.7994,
#         -15.1011,  -2.9943, -12.8442, -12.4257,   5.9124,  21.7910, -17.5845,
#          14.2734, -11.1817,  -3.8489,  18.5528,  -4.3444,   2.9528, -14.4490,
#          20.8377,  -1.4498, -14.2331,   8.8097, -14.6172, -15.7247,   4.0517,
#          22.3341,  -4.1940,  12.7000,  22.1335,  17.5656, -10.3854,  -0.7424,
#          -5.9829, -17.5394,   0.6291,  17.6129,  19.6493,   2.6770,   5.7086,
#          -9.2437,  17.6632,  -8.8629, -15.1730,   4.0499,  14.1320, -19.8647,
#          21.0865,   8.7370, -15.3089,  -4.3532,  20.2683, -16.6643,  -6.1312,
#           8.5709, -18.4239,  13.1199,  12.2930,  15.2506, -13.5218,  23.2037,
#         -12.9176,  23.1865, -21.1754, -19.6203,  14.4771,   2.9310,   1.8703],
#        grad_fn=<DivBackward0>)

# %%
-1.2867e-02/1.5765*1000
# Out:
# -8.16175071360609

# %%
model.fc1.bias[i]*1000
# Out:
# tensor(1.5765, grad_fn=<MulBackward0>)

# %%
image=images[1]

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
import sys
# Out:
# Mounted at /content/drive

# %%
data=np.load('/content/drive/My Drive/LCNN/Previous_code/uncoupled_deep_lbl/deepbu10_bl01_s08.npy',allow_pickle=True)

# %%
data
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
plt.plot(data[0][:10],'x-',label=r'$\beta=1$')
plt.plot(data[2][:10],'x-',label=r'$\beta \in [0.02,1]$')
plt.plot(data[1][:10],'x-',label=r'$\beta \in [1,20]$')
plt.plot(data[3][:10],'x-',label=r'$\beta \in [0.02,20]$')
plt.title(r'$s=0.2,l=0.001,m=0.9,n=1000,nosquare$')
plt.legend()
plt.savefig('scale0_2zoom.pdf')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a number, not 'list'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-7daa398aab07> in <module>()
# ----> 1 plt.plot(data[0][:10],'x-',label=r'$\beta=1$')
#       2 plt.plot(data[2][:10],'x-',label=r'$\beta \in [0.02,1]$')
#       3 plt.plot(data[1][:10],'x-',label=r'$\beta \in [1,20]$')
#       4 plt.plot(data[3][:10],'x-',label=r'$\beta \in [0.02,20]$')
#       5 plt.title(r'$s=0.2,l=0.001,m=0.9,n=1000,nosquare$')
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
# -> 1649             self.add_line(line)
#    1650         self._request_autoscale_view(scalex=scalex, scaley=scaley)
#    1651         return lines
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in add_line(self, line)
#    1848             line.set_clip_path(self.patch)
#    1849
# -> 1850         self._update_line_limits(line)
#    1851         if not line.get_label():
#    1852             line.set_label('_line%d' % len(self.lines))
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in _update_line_limits(self, line)
#    1870         Figures out the data limit of the given line, updating self.dataLim.
#    1871         """
# -> 1872         path = line.get_path()
#    1873         if path.vertices.size == 0:
#    1874             return
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/lines.py in get_path(self)
#    1025         """
#    1026         if self._invalidy or self._invalidx:
# -> 1027             self.recache()
#    1028         return self._path
#    1029
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/lines.py in recache(self, always)
#     673         if always or self._invalidy:
#     674             yconv = self.convert_yunits(self._yorig)
# --> 675             y = _to_unmasked_float_array(yconv).ravel()
#     676         else:
#     677             y = self._y
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py in _to_unmasked_float_array(x)
#    1315         return np.ma.asarray(x, float).filled(np.nan)
#    1316     else:
# -> 1317         return np.asarray(x, float)
#    1318
#    1319
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: setting an array element with a sequence.

# %%
def test(flag):
    learning_rate = 0.001
    torch.manual_seed(0)
    model = NeuralNet(input_size, hidden_size1,hidden_size2,hidden_size3,num_classes).to(device)
    
    print(flag)

    if flag>0:
        dataiter = iter(train_loader)
        images, labels = dataiter.next()
        images = images.view(images.shape[0], -1)
        if flag==1:
            adjust(model,images,threshold_u=1,threshold_l=0.01,scale=0.8)
        if flag==2:
            adjust(model,images,threshold_u=10,threshold_l=0.01,scale=0.8)
        if flag==3:
            adjust(model,images,threshold_u=10,threshold_l=1,scale=0.8)

    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate,momentum=0.9)
    #optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
    criterion = nn.NLLLoss()
    num_epochs=700
    dev=100
    losslist=[]


    totalloss=[]

    


    for epoch in range(num_epochs):
        loss_epoch=0
        for i, (images, labels) in enumerate(train_loader):  


            images = images.view(images.shape[0], -1)

            #print(images,labels)
            # Forward pass
            outputs = model(images)
            loss = criterion(outputs, labels)


            totalloss.append(loss.item())

            loss_epoch=loss_epoch+loss.item()
            # Backward and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        loss_epoch=loss_epoch/len(train_loader) 
        losslist.append(loss_epoch)
        if loss_epoch<0.02:
            break
        
        #print ('Epoch [{}/{}], Loss: {:.4f}' .format(epoch+1, num_epochs, loss_epoch))
        
    return losslist,totalloss

# %%
lt=[]
tt=[]
for ti in [0,1,2,3]:
    losslist,totalloss=test(ti)
    lt.append(losslist)
    tt.append(totalloss)
# Out:
# 0
# 1
# 2
# 3

# %%
with open('deepbu10_bl01_s08.npy', 'wb') as f:
    np.save(f, [lt,tt])

# %%
plt.plot(tt[0][:400],'x-',label=r'$\beta=1$')
plt.plot(tt[1][:400],'x-',label=r'$\beta \in [0.01,1]$')
plt.plot(tt[3][:400],'x-',label=r'$\beta \in [1,10]$')
plt.plot(tt[2][:400],'x-',label=r'$\beta \in [0.01,10]$')
plt.plot(totalloss[:400],'x-',label='layer by layer')
plt.plot([50,50],[0,2.5],color='black')
plt.title(r'$s=0.8,l=0.001,m=0.9,n=1000,square$')
plt.legend()
plt.ylabel('Loss')
plt.xlabel('Step')
plt.savefig('layerbylayer.pdf')

# %%
plt.plot(tt[0],'-',label=r'$\beta=1$')
plt.plot(tt[1],'-',label=r'$\beta \in [0.01,1]$')
plt.plot(tt[3],'-',label=r'$\beta \in [1,10]$')
plt.plot(tt[2],'-',label=r'$\beta \in [0.01,10]$')
plt.title(r'$s=0.8,l=0.001,m=0.9,n=1000,square$')
plt.plot(totalloss,'x-',label='layer by layer')
plt.plot([50,50],[0,2.5],color='black')
plt.ylabel('Loss')
plt.xlabel('Step')
plt.legend()
plt.savefig('layerbylayer1.pdf')

# %%
plt.plot(lt[0][:10],'x-',label=r'$\beta=1$')
plt.plot(lt[1][:10],'x-',label=r'$\beta \in [0.01,1]$')
plt.plot(lt[3][:10],'x-',label=r'$\beta \in [1,10]$')
plt.plot(lt[2][:10],'x-',label=r'$\beta \in [0.01,10]$')
plt.plot(losslist[:10],'x-',label='layer by layer')
plt.title(r'$s=0.8,l=0.001,m=0.9,n=1000,square$')

plt.legend()
plt.ylabel('Loss')
plt.xlabel('Step')
plt.savefig('layerbylayer2.pdf')

# %%
plt.plot(lt[0],'-',label=r'$\beta=1$')
plt.plot(lt[1],'-',label=r'$\beta \in [0.01,1]$')
plt.plot(lt[3],'-',label=r'$\beta \in [1,10]$')
plt.plot(lt[2],'-',label=r'$\beta \in [0.01,10]$')
plt.plot(losslist,'-',label='layer by layer')

plt.title(r'$s=0.8,l=0.001,m=0.9,n=1000,square$')
plt.ylabel('Loss')
plt.xlabel('Step')
plt.legend()
plt.savefig('layerbylayer3.pdf')

# %%
with open('deepbu10_bl01_s08.npy') as f:
    a=f

# %%
a=np.load('/content/drive/My Drive/LCNN/Previous_code/uncoupled_deep_lbl/deepbu10_bl01_s08.npy',allow_pickle=True)
tt=a[1]

# %%
model(images)
# Out:
# tensor([[-1.6430e+01, -1.9082e+01, -1.6934e+01, -1.5881e+01, -1.8228e+01,
#          -8.3446e-07, -1.4844e+01, -2.4172e+01, -2.0057e+01, -1.5571e+01],
#         [-1.5339e+01, -2.5421e+01, -1.7539e+01, -9.3753e+00, -1.9472e+01,
#          -4.7129e+00, -2.1154e+01, -1.1239e+01, -2.0045e+01, -9.1180e-03],
#         [-2.1252e+01, -1.7706e+01, -5.9605e-07, -1.4268e+01, -2.7702e+01,
#          -2.7206e+01, -3.1633e+01, -2.2352e+01, -2.1731e+01, -2.0110e+01],
#         [-2.2989e+01, -2.1492e+01,  0.0000e+00, -1.8642e+01, -2.3798e+01,
#          -2.9043e+01, -3.1586e+01, -2.0626e+01, -2.8690e+01, -2.5419e+01],
#         [-3.9339e-06, -2.6327e+01, -1.2451e+01, -2.2254e+01, -2.6496e+01,
#          -2.5606e+01, -2.5110e+01, -2.6474e+01, -1.9881e+01, -2.0869e+01],
#         [-1.3506e+01, -2.6581e+01, -1.9014e+01, -1.5087e+01, -1.6334e+01,
#          -1.5018e+01, -2.5797e+01, -5.3456e+00, -1.6952e+01, -4.7827e-03],
#         [-1.8832e+01, -1.6180e+01, -5.3644e-06, -1.3076e+01, -1.3134e+01,
#          -1.4690e+01, -1.4286e+01, -1.5731e+01, -1.9807e+01, -2.5568e+01],
#         [-1.2018e+01, -1.0184e+01, -7.7126e+00, -1.5936e+01, -1.3943e-03,
#          -7.4765e+00, -1.2759e+01, -8.0906e+00, -1.4897e+01, -1.0547e+01],
#         [-1.7272e+01, -1.8671e+01, -1.2623e+01, -1.9850e+01, -2.2620e+01,
#          -1.6587e+01, -4.5299e-06, -2.7615e+01, -1.3659e+01, -2.4164e+01],
#         [-1.7558e+01, -1.8089e+01, -9.7247e+00, -1.1683e+01, -3.1869e+01,
#          -1.8679e+01, -3.1110e+01, -7.4741e-05, -2.1265e+01, -1.1944e+01],
#         [-3.7539e+01, -2.9137e+01, -3.2005e+01,  0.0000e+00, -4.2354e+01,
#          -1.8854e+01, -4.6028e+01, -3.3223e+01, -2.5513e+01, -2.2596e+01],
#         [-1.9759e+01, -4.4741e-04, -1.3842e+01, -1.7921e+01, -1.0791e+01,
#          -1.5321e+01, -2.0648e+01, -7.7633e+00, -1.4634e+01, -1.6824e+01],
#         [-1.3079e+01, -6.9086e+00, -1.0025e+01, -6.0482e-02, -2.8890e+01,
#          -2.8535e+00, -1.8691e+01, -2.3962e+01, -1.8387e+01, -1.7628e+01],
#         [-1.8186e+01, -1.5750e+01, -9.8822e+00, -2.0929e+01, -1.5140e+01,
#          -1.2825e+01, -5.4239e-05, -2.4856e+01, -1.7821e+01, -2.3656e+01],
#         [-6.3276e+00, -1.1349e+01, -6.2684e+00, -5.5334e+00, -8.0667e+00,
#          -1.1054e+01, -8.0377e-03, -1.3343e+01, -1.1084e+01, -1.1242e+01],
#         [-1.4536e+01, -1.3056e+01, -1.8358e-05, -1.2224e+01, -1.5677e+01,
#          -1.6236e+01, -2.4528e+01, -1.1461e+01, -2.1438e+01, -1.5860e+01],
#         [-2.0178e+01, -1.7881e-05, -1.2033e+01, -1.9474e+01, -1.2494e+01,
#          -1.7490e+01, -2.4301e+01, -1.1845e+01, -1.3714e+01, -1.9220e+01],
#         [-2.0739e+01, -1.8715e+01, -1.1921e-06, -1.3644e+01, -2.4755e+01,
#          -2.3806e+01, -3.1198e+01, -1.6775e+01, -2.6571e+01, -2.4244e+01],
#         [-1.1041e+01, -1.3995e+01, -1.0636e+01, -1.3029e+01, -1.1309e+01,
#          -9.0639e+00, -1.7415e-04, -1.8374e+01, -1.4768e+01, -1.2871e+01],
#         [-1.9073e-06, -2.5383e+01, -1.3180e+01, -1.7446e+01, -3.1853e+01,
#          -2.3244e+01, -2.2199e+01, -3.1071e+01, -2.1641e+01, -2.2080e+01],
#         [-1.6088e+01, -2.1617e+01, -1.1264e+01, -1.2986e+01, -1.6887e+01,
#          -9.4576e+00, -3.0791e+01, -4.1536e-04, -8.5130e+00, -9.0189e+00],
#         [-2.4752e+01, -2.0870e+01, -1.3404e+01, -1.5991e+01, -1.7329e+01,
#          -1.7582e+01, -2.6396e+01, -2.1138e+01, -2.9802e-06, -1.3559e+01],
#         [-1.9301e+01, -1.9981e+01, -1.9517e+01, -1.6668e+01, -1.1592e+01,
#          -1.6167e+01, -2.5112e+01, -1.0063e+01, -1.5719e+01, -5.1974e-05],
#         [-1.9032e+01, -1.2714e+01, -7.3909e-06, -1.2864e+01, -1.3922e+01,
#          -1.4087e+01, -1.8782e+01, -1.7647e+01, -1.6084e+01, -1.9546e+01],
#         [-1.5617e+01, -1.1503e+01, -1.3996e+01, -1.4387e+01, -1.1524e+01,
#          -1.2612e+01, -2.4023e+01, -6.8159e+00, -1.2494e+01, -1.1255e-03],
#         [-9.6408e+00, -1.4595e+01, -1.0130e+01, -1.2982e+01, -1.6916e+01,
#          -1.1026e-04, -1.3079e+01, -1.9052e+01, -1.8566e+01, -1.4541e+01],
#         [-1.7367e+01, -6.8105e-04, -1.0361e+01, -1.5706e+01, -1.0568e+01,
#          -7.6813e+00, -1.7878e+01, -8.7519e+00, -1.2624e+01, -1.4733e+01],
#         [-2.1814e+01, -2.1299e+01, -1.6485e+01, -1.0807e+01, -2.0315e+01,
#          -2.0423e+01, -2.5617e+01, -2.4652e+01, -2.6583e-05, -1.1997e+01],
#         [-2.8814e+01, -2.5668e+01, -2.3294e+01, -9.0599e-06, -3.4753e+01,
#          -2.1373e+01, -3.8073e+01, -3.0464e+01, -1.2932e+01, -1.1919e+01],
#         [-2.6652e+01, -2.4077e+01, -3.0254e+01, -1.9508e+01, -2.7517e+01,
#           0.0000e+00, -3.0633e+01, -3.1478e+01, -2.1985e+01, -1.7567e+01],
#         [-1.0865e+01, -1.1651e+01, -8.6919e+00, -1.0898e+01, -1.1390e+01,
#          -1.1224e+01, -2.6282e-04, -1.4536e+01, -1.2431e+01, -1.0849e+01],
#         [-1.1075e+01, -1.7682e+01, -9.5423e+00, -1.8218e+01, -2.0094e+01,
#          -1.0903e+01, -2.6976e+01, -1.2175e+01, -1.3923e-04, -1.0468e+01]],
#        grad_fn=<LogSoftmaxBackward>)

# %%
t=0
c=0
with torch.no_grad():
    for i, (images, labels) in enumerate(valloader):
        images = images.view(images.shape[0], -1)
        outputs = model(images)
        t=t+(torch.argmax(outputs,dim=1) == labels).float().sum()
        c=c+len(outputs)

# %%
t/c
# Out:
# tensor(0.9735)

# %%
torch.argmax(outputs,dim=1)
# Out:
# tensor([5, 9, 2, 2, 0, 9, 2, 4, 6, 7, 3, 1, 3, 6, 6, 2, 1, 2, 6, 0, 7, 8, 9, 2,
#         9, 5, 1, 8, 3, 5, 6, 8])

# %%
labels
# Out:
# tensor([5, 9, 2, 2, 0, 9, 2, 4, 6, 7, 3, 1, 3, 6, 6, 2, 1, 2, 6, 0, 7, 8, 9, 2,
#         9, 5, 1, 8, 3, 5, 6, 8])

# %%
c=(torch.argmax(outputs,dim=1) == labels).float().sum()
# Out:
# tensor(32.)
